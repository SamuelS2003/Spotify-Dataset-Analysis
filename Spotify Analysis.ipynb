# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\USER\OneDrive\Documents\Data Analysis Projects\Spotify Analysis\spotify_tracks.csv')

# %%
df
# Out:
#                           id                                           name  \
# 0     7kr3xZk4yb3YSZ4VFtg2Qt                                       Acoustic
# 1     1kJygfS4eoVziBBI93MSYp                                       Acoustic
# 2     6lynns69p4zTCRxmmiSY1x                  Here Comes the Sun - Acoustic
# 3     1RC9slv335IfLce5vt9KTW                                    Acoustic #3
# 4     5o9L8xBuILoVjLECSBi7Vo  My Love Mine All Mine - Acoustic Instrumental
# ...                      ...                                            ...
# 6295  4uveHSzaz8YEbTF9j6QlCI                             Voyage to Atlantis
# 6296  4u15cjyziW2Ewn5Ek3082l                                       L'Oiseau
# 6297  56pHPaTeX2O9aVmTFYS8hV                                   The Daintree
# 6298  6Ldyc5TsR4kaUsuHKcB2AD                         The Sorcerers Symphony
# 6299  3ry0f8ybk8upUBIk8unvmF                                Fiore d'inverno
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6300 entries, 0 to 6299
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           6300 non-null   object
#  1   name         6300 non-null   object
#  2   genre        6300 non-null   object
#  3   artists      6300 non-null   object
#  4   album        6300 non-null   object
#  5   popularity   6300 non-null   int64
#  6   duration_ms  6300 non-null   int64
#  7   explicit     6300 non-null   bool
# dtypes: bool(1), int64(2), object(5)
# memory usage: 350.8+ KB

# %%
df.isnull().sum()
# Out:
# id             0
# name           0
# genre          0
# artists        0
# album          0
# popularity     0
# duration_ms    0
# explicit       0
# dtype: int64

# %%
df.drop('id', axis = 1, inplace = True)

# %%
df.describe()
# Out:
#         popularity   duration_ms
# count  6300.000000  6.300000e+03
# mean     30.754762  2.028477e+05
# std      19.948991  1.210299e+05
# min       0.000000  3.006000e+04
# 25%      16.000000  1.476870e+05
# 50%      29.000000  1.916070e+05
# 75%      45.000000  2.369625e+05
# max      90.000000  3.601658e+06

# %% [markdown]
# Data VIsualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#                                                name        genre  \
# 0                                          Acoustic     acoustic
# 1                                          Acoustic     acoustic
# 2                     Here Comes the Sun - Acoustic     acoustic
# 3                                       Acoustic #3     acoustic
# 4     My Love Mine All Mine - Acoustic Instrumental     acoustic
# ...                                             ...          ...
# 6295                             Voyage to Atlantis  world-music
# 6296                                       L'Oiseau  world-music
# 6297                                   The Daintree  world-music
# 6298                         The Sorcerers Symphony  world-music
# 6299                                Fiore d'inverno  world-music
#
#                                          artists  \
# 0                                  Billy Raffoul
# 1                                  Billy Raffoul
# ...

# %%
#Genre Analysis

genre_popular = df.groupby('genre')['popularity'].mean().head(10).sort_values(ascending=False)

#Plotting
plt.figure(figsize=(10,7))

plt.bar(genre_popular.index, genre_popular.values, color ='blue')
plt.title('Genre Popularity')
plt.xlabel('Genre')
plt.ylabel('Popularity')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
#Cleaning the Artist Coloumn
df['artists'] = df['artists'].str.split(', ')
df = df.explode('artists').reset_index(drop=True)

#Artist Popularity Analysis

artist_popular = df.groupby('artists')['popularity'].mean().head(10).sort_values(ascending=False)

#Plotting
plt.figure(figsize=(10,7))

plt.bar(artist_popular.index, artist_popular.values, color = ['red','tomato'])
plt.title('Artist Popularity')
plt.xlabel('Artists')
plt.ylabel('Popularity')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
#Album Popularity Analysis

album_popular = df.groupby('album')['popularity'].mean().head(10).sort_values(ascending=False)

#Plotting
plt.figure(figsize=(7,7))

plt.bar(album_popular.index, album_popular.values, color = ['red','tomato'])
plt.title('Album Popularity', fontsize=15)
plt.xlabel('Album')
plt.ylabel('Popularity')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
#Album Playtime Analysis

album_playtime = df.groupby('album')['duration_ms'].mean().head(10).sort_values(ascending=False)

#Plotting
plt.figure(figsize=(7,7))

plt.bar(album_playtime.index, album_playtime.values, color = ['Blue','tomato'])
plt.title('Album Playtime', fontsize=15)
plt.xlabel('Album')
plt.ylabel('Playtime in Milliseconds')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

plt.show()

# %%
#Artist and Album Analysis
most_album = df.groupby('artists')['album'].nunique().sort_values(ascending=False).head(10)
sns.barplot(x=most_album.values, y=most_album.index, palette='viridis')
plt.title('Artist with most albums')
plt.ylabel('Artists')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10556\2635696643.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=most_album.values, y=most_album.index, palette='viridis')

# %%
#Explicit Content Analysis
explicit = df['explicit'].value_counts()
plt.pie(
    explicit, 
    labels=explicit.index, 
    autopct='%1.f%%', 
    colors=['Red','tomato']
)
plt.title('Explicit Content Ratio')
plt.show()

# %%
#Albums with Explict Content
explicit_albums = df[df['explicit']==True]

artist_explicit = explicit_albums.groupby('album')['popularity'].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,7))
sns.barplot(x=artist_explicit.values, y=artist_explicit.index, palette = 'mako')
plt.title('Explicit Albums Ranking', fontsize=15)
plt.ylabel('Albums', fontsize = 15)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10556\1994974075.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=artist_explicit.values, y=artist_explicit.index, palette = 'mako')
